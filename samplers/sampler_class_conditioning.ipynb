# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/proyecto_AAIII_02_diffusion_models
# Out:
# /content/drive/MyDrive/proyecto_AAIII_02_diffusion_models

# %% [markdown]
# ## Imports

# %%
import torch

from src.class_conditional import generate_conditional_images
from src.diffusion_utilities import plot_image_grid

# %% [markdown]
# ## Device

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)

print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# ## Parámetros de usuario

# %%
digit = 9
color_name = "magenta"
n_images = 9

checkpoint_dir = "./checkpoints/conditional_cmnist_ou_cosine/checkpoint_conditional_ou_cosine_epoch500.pth"

# %% [markdown]
# ## Generación

# %%
images = generate_conditional_images(
    digit=digit,
    color_name=color_name,
    checkpoint_path=checkpoint_dir,
    n_images=n_images,
    n_steps=1000,
    n_corrector_steps=1,
    snr=0.16,
    device=device,
)

# %% [markdown]
# ## Visualizacion

# %%
_ = plot_image_grid(
    images=images,
    figsize=(5, 5),
    n_rows=3,
    n_cols=3,
    cmap=None,
)
